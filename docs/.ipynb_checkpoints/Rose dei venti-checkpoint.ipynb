# %% [markdown]
# # Calcolo delle rose dei venti di una stazione qualunque e di un periodo qualunque
#
# **fase 1: identificazione dei sensori**
#
# occorre indicare i codici sensore di VV e DV
#
# occorre specificare il periodo
#
# **fase 2: estrazione dati**
#
# **fase 3: creazione della rosa**

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np
from math import pi

# %%
data_inizio='2017-06-01'
data_fine='2017-06-30 23:59'

# %%
from sqlalchemy import *
engine = create_engine('mysql+pymysql://guardone:guardone@10.10.0.6/METEO')
conn=engine.connect()
sql_query_dv="select * from M_AnemometriDV_2017 where IDsensore=14328 and Data_e_ora between '"+ data_inizio+"' and '"+data_fine+"'"
sql_query_vv="select * from M_AnemometriVV_2017 where IDsensore=5127 and Data_e_ora between '"+ data_inizio+"' and '"+data_fine+"'"
#wd= conn.execute("select * from M_AnemometriDV_2017 where IDsensore=9815 and Data_e_ora between '2017-06-15' and '2017-06-23 23:50'")
#ws= conn.execute("select * from M_AnemometriVV_2017 where IDsensore=9821 and Data_e_ora between '2017-06-15' and '2017-06-23 23:50'")
#wd
#df = pd.DataFrame({"speed": ws, "direction": wd})
#df
#for row in wd:
#    print (row['Data_e_ora'],row['Misura'])

# %%
df_dv=pd.read_sql(sql_query_dv, conn)
df_vv=pd.read_sql(sql_query_vv, conn)

# %%
from windrose import WindroseAxes

# %%
df = pd.DataFrame({"speed": df_vv['Misura'], "direction": df_dv['Misura']})

# %%
ax = WindroseAxes.from_ax()
ax.bar(df.direction, df.speed, normed=True, opening=0.6, bins=(1,3,5,10), edgecolor='white')

# %%
ax.bar(df.direction, df.speed, normed=True, nsector=16)
table = ax._info['table']
wd_freq = np.sum(table, axis=0)

# %%
direction = ax._info['dir']
wd_freq = np.sum(table, axis=0)
plt.bar(np.arange(16), wd_freq, align='center')
xlabels = ('N','','N-E','','E','','S-E','','S','','S-O','','O','','N-O','')
xticks=np.arange(16)
gca().set_xticks(xticks)
draw()
gca().set_xticklabels(xlabels)
draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d8abda708a48> in <module>()
#       4 xlabels = ('N','','N-E','','E','','S-E','','S','','S-O','','O','','N-O','')
#       5 xticks=np.arange(16)
# ----> 6 gca().set_xticks(xticks)
#       7 draw()
#       8 gca().set_xticklabels(xlabels)
#
# NameError: name 'gca' is not defined
