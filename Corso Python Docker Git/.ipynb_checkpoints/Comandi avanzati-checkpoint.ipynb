# %% [markdown]
# ## Leggere e scrivere csv

# %% [markdown]
# Per leggere e scrivere csv conviene utilizzare dei _Moduli_ predefiniti.
#
# Quelli più utili sono:
#
# _**pandas**_ : pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language (https://pandas.pydata.org/).
#
# _**numpy**_: (https://www.numpy.org/)
# NumPy is the fundamental package for scientific computing with Python. It contains among other things:
#
# - a powerful N-dimensional array object
# - sophisticated (broadcasting) functions
# - tools for integrating C/C++ and Fortran code
# - useful linear algebra, Fourier transform, and random number capabilities

# %%
import pandas as pd

# %% [markdown]
# ## leggere un file creato dall'estrattore

# %%
nome='/home/jovyan/work/8140_H_1.txt'
df=pd.read_csv(nome, sep='\t',header=None,names=['IDsensore','DataOra','Misura','Valido'])

# %%
df.head()
# Out:
#    IDsensore                  DataOra  Misura  Valido
# 0       8140  2018-01-01 01:00:00.000     3.2     100
# 1       8140  2018-01-01 02:00:00.000     3.2     100
# 2       8140  2018-01-01 03:00:00.000     2.8     100
# 3       8140  2018-01-01 04:00:00.000     2.7     100
# 4       8140  2018-01-01 05:00:00.000     2.8     100

# %% [markdown]
# ## scrivere un csv

# %%
df.to_csv('file_di_prova.csv',sep=',')

# %% [markdown]
# # plottare con plotly

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plot([go.Scatter(x=df.DataOra, y=df.Misura)])
# Out:
# 'temp-plot.html'

# %%
import matplotlib.pyplot as plt
plt.plot(df.Misura)

# %% [markdown]
# # accedere al database

# %%
from sqlalchemy import *

# %% [markdown]
# definisco la query, esattamente come SQL

# %%
Query2="Select A_Stazioni.IDstazione,A_Sensori.IDsensore,A_Sensori.NOMEtipologia,DataFine,DataInizio,Aggregazione from A_Sensori join A_Stazioni on A_Sensori.IDstazione=A_Stazioni.IDstazione where IDrete in (1,4) and NOMEtipologia in ('T','I','Q','N','RN','RG','UR','DV','VV','PP');"

# %%
engine = create_engine('mysql+mysqlconnector://guardone:guardone@10.10.0.6/METEO?charset=utf8')
conn=engine.connect()
df_sensori=pd.read_sql(Query2, conn)

# %%
df_sensori
# Out:
#       IDstazione  IDsensore NOMEtipologia    DataFine  DataInizio Aggregazione
# 0              3          3             I        None  1987-11-24         None
# 1              3          9            PP        None  1987-11-24         None
# 2              3         12             T        None  1987-11-24         None
# 3              3      17533            UR        None  2019-01-07         None
# 4              9         16             I        None  1989-03-24         None
# 5             33         46            PP        None  1989-11-10         None
# 6             33         56             T        None  1989-11-10         None
# 7             33         64             I        None  1989-11-10         None
# 8             33      17545            UR        None  2018-12-28         None
# 9             58        115             T        None  2001-12-01         None
# 10            58        116            PP        None  2002-01-01         None
# ...

# %%
Query='SELECT * FROM `M_Termometri_2018` where IDsensore=8140'
df_meteo=pd.read_sql(Query, conn)

# %%
df_meteo[df_meteo.Flag_manuale != 'E']
# Out:
#       IDsensore          Data_e_ora  Misura  Flag_manuale_DBunico  \
# 1          8140 2018-01-01 01:00:00     3.2                  -100
# 2          8140 2018-01-01 02:00:00     3.2                  -100
# 3          8140 2018-01-01 03:00:00     2.8                  -100
# 4          8140 2018-01-01 04:00:00     2.7                  -100
# 5          8140 2018-01-01 05:00:00     2.8                  -100
# 6          8140 2018-01-01 06:00:00     2.1                  -100
# 7          8140 2018-01-01 07:00:00     1.5                  -100
# 8          8140 2018-01-01 08:00:00     1.1                  -100
# 9          8140 2018-01-01 09:00:00     0.9                  -100
# 10         8140 2018-01-01 10:00:00     0.6                  -100
# 11         8140 2018-01-01 11:00:00     1.2                  -100
# 12         8140 2018-01-01 12:00:00     1.9                  -100
# 13         8140 2018-01-01 13:00:00     1.6                  -100
# ...

# %%
plt.plot(df_meteo[df_meteo.Flag_manuale != 'E'].Misura)

# %%
plot([go.Scatter(x=df.DataOra, y=df_meteo.Misura)])
# Out:
# 'temp-plot.html'

# %%
trace0=go.Scatter(x=df.DataOra, y=df.Misura)
trace1=go.Scatter(x=df_meteo.Data_e_ora, y=df_meteo.Misura)
data=[trace0,trace1]
plot(data)
# Out:
# 'temp-plot.html'

# %% [markdown]
# importiamo i 10 minuti

# %%
nome='/home/jovyan/work/8140_P10_1.txt'
df10=pd.read_csv(nome, sep='\t',header=None,names=['IDsensore','DataOra','Misura','Valido'])

# %% [markdown]
# aggiungiamo la serie da plottare

# %%
trace2=go.Scatter(x=df10.DataOra, y=df10.Misura)

# %%
data=[trace0,trace2]

# %%
plot(data)
# Out:
# 'temp-plot.html'

# %% [markdown]
# se vogliamo eliminare i dati non validi

# %%
import numpy as np

# %%
df10[df10.Misura==-999]=np.nan
